# %%
import pandas as pd

# %%
df = pd.read_csv("top_500_artists_deduplicate.csv")
df
# Out:
#                                              name  \
# 0                   Jimmy Cooks (feat. 21 Savage)
# 1                 WAIT FOR U (feat. Drake & Tems)
# 2                                       One Dance
# 3     Knife Talk (with 21 Savage ft. Project Pat)
# 4                                      God's Plan
# ...                                           ...
# 4571                                     Woodlawn
# 4572                                   Invincible
# 4573              Compensating (feat. Young Thug)
# 4574                     FEEL SOMETHING DIFFERENT
# 4575                          Mad Funny Freestyle
#
#                                                   album           artist  \
# 0                                   Honestly, Nevermind            Drake
# 1                                     I NEVER LIKED YOU           Future
# 2                                                 Views            Drake
# ...

# %%
df.sort_values(['popularity'],ascending=False).head(20)
# Out:
#                                        name  \
# 280               Unholy (feat. Kim Petras)
# 2470  Quevedo: Bzrp Music Sessions, Vol. 52
# 1632                             La Bachata
# 10                          Me Porto Bonito
# 223                         I'm Good (Blue)
# 11                         Tití Me Preguntó
# 611                         I Ain't Worried
# 420                     Under The Influence
# 12                                   Efecto
# 1398                          Glimpse of Us
# 13                            Ojitos Lindos
# 566                                PROVENZA
# 14                              Moscow Mule
# 15                                 Neverita
# 411                      Late Night Talking
# 410                               As It Was
# 1214                        Sweater Weather
# 299                                 CUFF IT
# 16                                    Tarot
# 513                                  LOKERA
#
# ...

# %%
df
# Out:
#                                              name  \
# 0                   Jimmy Cooks (feat. 21 Savage)
# 1                 WAIT FOR U (feat. Drake & Tems)
# 2                                       One Dance
# 3     Knife Talk (with 21 Savage ft. Project Pat)
# 4                                      God's Plan
# ...                                           ...
# 4571                                     Woodlawn
# 4572                                   Invincible
# 4573              Compensating (feat. Young Thug)
# 4574                     FEEL SOMETHING DIFFERENT
# 4575                          Mad Funny Freestyle
#
#                                                   album           artist  \
# 0                                   Honestly, Nevermind            Drake
# 1                                     I NEVER LIKED YOU           Future
# 2                                                 Views            Drake
# ...
